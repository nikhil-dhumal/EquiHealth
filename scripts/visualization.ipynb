# %% [markdown]
# ### Visualization of scraped data

# %% [markdown]
# This file will contain the visualizations of scraped data.
#
# We will use several websites for scraping data for visualization, some of them may be:<br>
# -  https://www.pib.gov.in/PressReleasePage.aspx?PRID=1539877 <br>
# -  https://www.mospi.gov.in/sites/default/files/publication_reports/KI_Health_75th_Final.pdf <br>
# -  https://en.wikipedia.org/wiki/List_of_hospitals_in_India

# %% [markdown]
# We will mainly use python's numpy, matplotlib for the same.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# A sample which bar plots the number of hospitals in 4 states: Andhra Pradesh, Arunachal Pradesh, Assam and Bihar. Data taken from first link above.

# %%
numhospitals = [1666, 199, 1220, 2146]
plt.bar(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar'], numhospitals)
plt.show()
